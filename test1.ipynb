# %%
people = ['max','vlad','alina','vadim',5,6,True,False]
for person in people:
    print(person)
# Out:
# max
# vlad
# alina
# vadim
# 5
# 6
# True
# False

# %%
i=0
while i<len(people):
    print(people[i])
    i+=1
# Out:
# max
# vlad
# alina
# vadim
# 5
# 6
# True
# False

# %%
ages={'vlad':'posdnyakov podpisatsia','alina':22,'nikita':1488}
for name,age in ages.items():
    print(name,age)
# Out:
# vlad posdnyakov podpisatsia
# alina 22
# nikita 1488

# %%
number = [23,556,33,66]
print(number,"\n",sorted(number))
# Out:
# [23, 556, 33, 66]
#  [23, 33, 66, 556]

# %%
nameBill=["artem","vlad","egor","daniil"]
simple_dict={}
for name,age in zip(nameBill,number,strict=True):
    simple_dict[name]=age
print(simple_dict)
# Out:
# {'artem': 23, 'vlad': 556, 'egor': 33, 'daniil': 66}
